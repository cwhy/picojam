# %%
import sys

sys.path.append("../berries")

# %%
from my_datasets import load_supervised_1d

#n_samples, d_x, d_y, X, y, X_test, y_test = load_supervised_1d("fashion_mnist")
n_samples, d_x, d_y, X, y, X_test, y_test = load_supervised_1d("mnist")
# Out:
# /home/owner/Projects/picojam/pico/.venv/lib/python3.10/site-packages/datasets/load.py:1429: FutureWarning: The repository for mnist contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/mnist
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
X = X / 255.0
X_test = X_test / 255.0

# %%
d_h_layer = 256
d_h = 256
n_layers = 2
d_in = d_x
# d_out = d_y
d_out = d_x
#d_code = 16
#total_codes = 128
sentence_len = 1024
n_levels = 128

# %%
import nn
import importlib
importlib.reload(nn)
from nn import mglu_net_config, mglu_net, rmglu_net
import pf
importlib.reload(pf)
from pf import F, _

from jax.numpy import mean, exp
from jax.lax import stop_gradient, round
from jax.nn import tanh


# def vae_config(d_in, d_h_layer, d_vae_h, d_h, n_layers, init):
#     return {
#         "encoder":mglu_net_config(d_in, d_h_layer, 2 * d_vae_h, d_h, n_layers, init),
#         "decoder": mglu_net_config(d_vae_h, d_h_layer, d_in, d_h, n_layers, init)}

def vqvae_config(init):
    return {
        "encoder": mglu_net_config(d_x, d_h_layer, sentence_len, d_h, n_layers, init),
        "decoder": mglu_net_config(sentence_len, d_h_layer, d_x, d_h, n_layers, init)
    }


def quantize(z):
    zp = round(n_levels/2 * tanh(z))
    return z + stop_gradient(zp -z)


def nearest_code(z):
    return round(z)



def vqvae(W, x):
    z = mglu_net(x, W["encoder"])
    z_q = quantize(z)
    x_q = mglu_net(z_q.reshape(-1), W["decoder"])
    return x_q, z, z_q

def vqvae_losses(W, x):
    x_q, z, z_q = vqvae(W, x)
    return ((x_q - x) ** 2).mean()



loss_b = F(vqvae_losses).vmap((None, 0), 0)
loss_bm = loss_b >> mean

# %%
# test neareset code
import init_utils
import random_utils
seed = 0
key_gen = random_utils.infinite_safe_keys(seed)

# %%
import optax
from jax import grad, jit
from jax.tree_util import tree_map
from nn import init_weights, fmt_weights



lr = 0.0001
mask_fn = lambda p: tree_map(lambda x: not isinstance(x, int), p)
# opt = optax.multi_transform({"sgd": optax.rmsprop(lr), "zero": optax.set_to_zero()}, mask_fn)
opt = optax.masked(optax.adam(lr), mask_fn)

# method = {"type": "zer0", "std": 0.001}
method = {"type": "normal", "std": 0.01}
# method = {"type": "normal", "std": 0.1}
W = init_weights(next(key_gen), vqvae_config(method))
print(fmt_weights(W)[0])
print(vqvae(W, X_test[0, :]))
loss0 = loss_bm(W, X_test[:100, :])
print(loss0)
state = opt.init(W)

@jit
def update(W, x, opt_state):
    grads = grad(loss_bm)(W, x)
    updates, opt_state = opt.update(grads, opt_state)
    new_W = optax.apply_updates(W, updates)
    return new_W, opt_state
# Out:
# encoder:
#     mglu:
#         tuple:
#             sglu:
#                 wv:
#                     array shape: (784, 256)
#                 wu:
#                     array shape: (784, 256)
#                 wo:
#                     array shape: (256, 256)
#                 total params: 466944
#             rmsn:
#                 d:
#                     256.0
#                 total params: 1
#             total params: 466945
#         tuple:
#             sglu:
#                 wv:
#                     array shape: (256, 256)
#                 wu:
#                     array shape: (256, 256)
#                 wo:
#                     array shape: (256, 256)
#                 total params: 196608
#             rmsn:
#                 d:
#                     256.0
#                 total params: 1
#             total params: 196609
#         total params: 663554
#     sglu:
#         wv:
#             array shape: (256, 256)
#         wu:
#             array shape: (256, 256)
#         wo:
#             array shape: (256, 1024)
#         total params: 393216
#     total params: 1056770
# decoder:
#     mglu:
#         tuple:
#             sglu:
#                 wv:
#                     array shape: (1024, 256)
#                 wu:
#                     array shape: (1024, 256)
#                 wo:
#                     array shape: (256, 256)
#                 total params: 589824
#             rmsn:
#                 d:
#                     256.0
#                 total params: 1
#             total params: 589825
#         tuple:
#             sglu:
#                 wv:
#                     array shape: (256, 256)
#                 wu:
#                     array shape: (256, 256)
#                 wo:
#                     array shape: (256, 256)
#                 total params: 196608
#             rmsn:
#                 d:
#                     256.0
#                 total params: 1
#             total params: 196609
#         total params: 786434
#     sglu:
#         wv:
#             array shape: (256, 256)
#         wu:
#             array shape: (256, 256)
#         wo:
#             array shape: (256, 784)
#         total params: 331776
#     total params: 1118210
# total params: 2174980
#
# (Array([-8.35417770e-04,  2.07500788e-03,  1.64483709e-03, -1.15735978e-02,
#         1.28710363e-03, -4.69152397e-03,  1.13869403e-02,  2.99691688e-04,
#        -3.70575022e-03,  6.52617868e-03,  4.83955303e-03,  8.90759937e-03,
#        -1.03005406e-03, -1.44504989e-03, -7.39049399e-04,  6.43296121e-03,
#         6.41886727e-04, -2.09535146e-03, -2.03883322e-03, -2.01974413e-03,
#         4.16754419e-03, -2.97200214e-03,  6.55479031e-04, -3.15149222e-03,
#         6.41121995e-03, -1.33656478e-03,  3.55836004e-03,  2.14501796e-03,
#        -6.64225686e-03, -1.48187252e-03, -1.99750415e-03,  7.40966876e-04,
#        -9.80773661e-03, -3.51656973e-03,  7.00468803e-03,  4.99439426e-04,
#        -4.86916164e-03, -1.10320281e-03,  3.32546467e-03, -5.82716335e-03,
#        -9.19630984e-05, -5.54736331e-03,  1.14021963e-02, -3.65569955e-03,
#        -1.35228271e-04, -4.36722720e-03,  8.10476253e-04, -2.16659671e-03,
#        -1.31682807e-03,  6.08277041e-03, -7.08227605e-03, -4.00666380e-03,
#        -1.62230467e-03, -3.54572572e-03,  2.73745973e-03,  4.53120470e-03,
#         1.00652752e-02, -1.12897437e-03, -1.46460487e-03, -1.21917641e-02,
#        -1.75838219e-03,  8.44171504e-04, -2.01691920e-03,  1.21852371e-03,
#        -3.37074697e-03, -5.80403488e-04,  6.75081741e-04,  7.83320796e-03,
#        -6.38633687e-03,  2.12030928e-03,  1.70601089e-03, -7.06728594e-03,
#         1.04419682e-02,  6.23944495e-03,  7.51941465e-04,  7.97687005e-03,
#        -1.37926475e-03, -3.91649036e-03,  2.92363251e-03, -2.72451225e-03,
#         1.37220193e-02,  4.46804147e-03, -8.27276800e-03,  4.65710531e-04,
#        -2.10095663e-04, -7.37292692e-04, -6.13264227e-03,  2.77834898e-03,
#        -3.33369803e-03, -2.67074676e-04,  3.35749891e-03, -1.00538135e-02,
#         4.99338377e-03, -3.20904795e-03,  1.92443852e-03,  2.37497315e-03,
#        -1.95952412e-03, -3.28877941e-04,  5.36157470e-03,  8.47199932e-03,
#         8.42825044e-04,  8.39233678e-03, -1.21465567e-02,  3.82552855e-03,
#         7.03190500e-03, -7.27453548e-03,  1.04023339e-02,  7.11890589e-03,
#         1.98405026e-03, -5.86819695e-03,  7.34010572e-03,  5.82660781e-03,
#         2.30471743e-03,  8.18802509e-03, -7.11537153e-03, -5.98463416e-03,
#         1.29794190e-02, -8.00162787e-04, -3.92582826e-03, -2.02995120e-03,
#        -4.21995530e-04, -7.02806376e-03, -9.23133176e-03,  3.70521401e-03,
#        -2.57225148e-03, -1.62298640e-03, -3.42864939e-03,  9.80131328e-03,
#        -7.27228471e-04,  2.62396480e-03, -2.18328740e-03, -1.73115381e-03,
#        -1.29413605e-02,  6.68815663e-03, -2.98940903e-03, -1.28139406e-02,
#         5.88393537e-03, -6.83844090e-04, -5.13084466e-04,  7.25017441e-03,
#        -2.23269034e-03, -4.27454244e-03, -7.34403729e-03, -1.10786641e-04,
#         4.12704935e-03, -4.90050670e-03, -1.09921489e-02, -3.31073254e-03,
#         9.64995008e-04, -9.10254568e-03, -7.99524412e-03, -1.07750285e-03,
#        -6.94283051e-04,  6.17572665e-03,  1.34866813e-03, -5.17608505e-03,
#         1.27094542e-03, -8.51202011e-03,  9.92170535e-05, -9.91105102e-04,
#        -2.75442051e-03,  6.73513487e-03, -4.38721199e-03,  5.34030469e-03,
#        -8.28852225e-03,  1.07721682e-03, -1.54422666e-03, -1.51194318e-03,
#        -5.00953430e-03, -3.70532274e-03,  3.94836068e-03,  3.39093059e-03],      dtype=float32), Array([ 0.00892152, -0.00321105, -0.00380681, ...,  0.00010143,
#         0.00114618, -0.00147975], dtype=float32), Array([1., 0., 0., ..., 0., 0., 0.], dtype=float32))
# 0.10191814

# %%
from plot_utils import visualize_matrix
from IPython.display import display
import math, random
import jax.numpy as np


def loss_b_dt(W):
    return mean(loss_b(W, X_test[:100, :]))


batch_size = 64

def sample():
    return X[random.sample(range(n_samples), batch_size), :]

for i in range(5000):
    data = sample()
    W, state = update(W, data, state)
    if i % 200 == 0:
        print(loss_bm(W, data), loss_b_dt(W))
    if i % 1000 == 0:
        image_id = math.ceil(random.uniform(0, 1) * n_samples)
        plt, __, __ = visualize_matrix(data[image_id, :].reshape(28, 28), dpi=100)
        display(plt)

        out = vqvae(W, data[image_id, :])[0]
        plt, __, __ = visualize_matrix(out.reshape(28, 28), dpi=100)
        display(plt)


print(loss_b_dt(W))
# Out:
# 0.112999566 0.101915404
# 0.060150072 0.05768095
# 0.056328293 0.050624058
# 0.04566787 0.04395829
# 0.03537096 0.036860842
# 0.03401992 0.032173842
# 0.029066645 0.028585443
# 0.02696017 0.026503857
# 0.02459387 0.024701782
# 0.026415844 0.023180852
# 0.02143715 0.021737924
# 0.0205658 0.020806836
# 0.018264795 0.019565752
# 0.020129807 0.019015474
# 0.017322898 0.018096272
# 0.016401513 0.017383501
# 0.016118577 0.016825229
# 0.016684301 0.0163277
# 0.015984822 0.01591399
# 0.015408759 0.015558996
# 0.015004073 0.014948063
# 0.014130857 0.014658547
# 0.015623823 0.014419179
# 0.014087885 0.013848088
# 0.012468304 0.01353237
# 0.013416027
